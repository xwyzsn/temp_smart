# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Fig. 2

# %%
from smart_choice.datanodes import DataNodes

def payoff_fn(values, probabilities, branches):
    bid = values["bid"] if "bid" in values.keys() else 0
    competitor_bid = (
        values["competitor_bid"] 
        if "competitor_bid" in values.keys() else 0
    )
    cost = values["cost"] if "cost" in values.keys() else 0
    return (bid - cost) * (1 if bid < competitor_bid else 0)


nodes = DataNodes()
nodes.add_decision(
    name="bid",
    branches=[
        ("low", 300, "competitor_bid"),
        ("medium", 500, "competitor_bid"),
        ("high", 700, "competitor_bid"),
        ("no-bid", 0, "profit"),
    ],
    maximize=True,
)
nodes.add_chance(
    name="competitor_bid",
    branches=[
        ("low", 0.35, 400, "cost"),
        ("medium", 0.50, 600, "cost"),
        ("high", 0.15, 800, "cost"),
    ],
)
nodes.add_chance(
    name="cost",
    branches=[
        ("low", 0.25, 200, "profit"),
        ("medium", 0.50, 400, "profit"),
        ("high", 0.25, 600, "profit"),
    ],
)
nodes.add_terminal(name="profit", payoff_fn=payoff_fn)
nodes
# Out:
# 0  D bid             low                     300.00 competitor_bid
#                      medium                  500.00 competitor_bid
#                      high                    700.00 competitor_bid
#                      no-bid                    0.00 profit
# 1  C competitor_bid  low             .3500   400.00 cost
#                      medium          .5000   600.00 cost
#                      high            .1500   800.00 cost
# 2  C cost            low             .2500   200.00 profit
#                      medium          .5000   400.00 profit
#                      high            .2500   600.00 profit
# 3  T profit

# %% [markdown]
# # Fig. 3

# %%
from smart_choice.decisiontree import DecisionTree

tree = DecisionTree(nodes=nodes)
tree
# Out:
# STRUCTURE     NAMES           OUTCOMES         PROBABILIES
# ------------------------------------------------------------------
# 0D1 14 27 40  bid             300 500 700 0
# 1C2 6 10      competitor_bid  400 600 800      .3500 .5000 .1500
# 2C3 4 5       cost            200 400 600      .2500 .5000 .2500
# 3T            profit
# 4T            profit
# 5T            profit
# 6C7 8 9       cost            200 400 600      .2500 .5000 .2500
# 7T            profit
# 8T            profit
# 9T            profit
# 10C11 12 13   cost            200 400 600      .2500 .5000 .2500
# 11T           profit
# 12T           profit
# 13T           profit
# 14C15 19 23   competitor_bid  400 600 800      .3500 .5000 .1500
# 15C16 17 18   cost            200 400 600      .2500 .5000 .2500
# 16T           profit
# 17T           profit
# 18T           profit
# 19C20 21 22   cost            200 400 600      .2500 .5000 .2500
# 20T           profit
# 21T           profit
# 22T           profit
# 23C24 25 26   cost            200 400 600      .2500 .5000 .2500
# 24T           profit
# 25T           profit
# 26T           profit
# 27C28 32 36   competitor_bid  400 600 800      .3500 .5000 .1500
# 28C29 30 31   cost            200 400 600      .2500 .5000 .2500
# 29T           profit
# 30T           profit
# 31T           profit
# 32C33 34 35   cost            200 400 600      .2500 .5000 .2500
# 33T           profit
# 34T           profit
# 35T           profit
# 36C37 38 39   cost            200 400 600      .2500 .5000 .2500
# 37T           profit
# 38T           profit
# 39T           profit
# 40T           profit

# %%
tree.display()
# Out:
# |
# |
# \---[D] #0
#      | bid
#      | low               300.00
#      +----------------------[C] #1
#      |                       | competitor_bid
#      |                       | low             .3500   400.00
#      |                       +----------------------------[C] #2
#      |                       |                             | cost
#      |                       |                             | low             .2500   200.00
#      |                       |                             | medium          .5000   400.00
#      |                       |                             \ high            .2500   600.00
#      |                       | competitor_bid
#      |                       | medium          .5000   600.00
#      |                       +----------------------------[C] #6
#      |                       |                             | cost
#      |                       |                             | low             .2500   200.00
#      |                       |                             | medium          .5000   400.00
#      |                       |                             \ high            .2500   600.00
#      |                       | competitor_bid
#      |                       | high            .1500   800.00
#      |                       \----------------------------[C] #10
#      |                                                     | cost
#      |                                                     | low             .2500   200.00
#      |                                                     | medium          .5000   400.00
#      |                                                     \ high            .2500   600.00
#      | bid
#      | medium            500.00
#      +----------------------[C] #14
#      |                       | competitor_bid
#      |                       | low             .3500   400.00
#      |                       +----------------------------[C] #15
#      |                       |                             | cost
#      |                       |                             | low             .2500   200.00
#      |                       |                             | medium          .5000   400.00
#      |                       |                             \ high            .2500   600.00
#      |                       | competitor_bid
#      |                       | medium          .5000   600.00
#      |                       +----------------------------[C] #19
#      |                       |                             | cost
#      |                       |                             | low             .2500   200.00
#      |                       |                             | medium          .5000   400.00
#      |                       |                             \ high            .2500   600.00
#      |                       | competitor_bid
#      |                       | high            .1500   800.00
#      |                       \----------------------------[C] #23
#      |                                                     | cost
#      |                                                     | low             .2500   200.00
#      |                                                     | medium          .5000   400.00
#      |                                                     \ high            .2500   600.00
#      | bid
#      | high              700.00
#      +----------------------[C] #27
#      |                       | competitor_bid
#      |                       | low             .3500   400.00
#      |                       +----------------------------[C] #28
#      |                       |                             | cost
#      |                       |                             | low             .2500   200.00
#      |                       |                             | medium          .5000   400.00
#      |                       |                             \ high            .2500   600.00
#      |                       | competitor_bid
#      |                       | medium          .5000   600.00
#      |                       +----------------------------[C] #32
#      |                       |                             | cost
#      |                       |                             | low             .2500   200.00
#      |                       |                             | medium          .5000   400.00
#      |                       |                             \ high            .2500   600.00
#      |                       | competitor_bid
#      |                       | high            .1500   800.00
#      |                       \----------------------------[C] #36
#      |                                                     | cost
#      |                                                     | low             .2500   200.00
#      |                                                     | medium          .5000   400.00
#      |                                                     \ high            .2500   600.00
#      \ no-bid              0.00

# %% [markdown]
# # Fig. 4

# %%
tree.evaluate()
tree.rollback()
tree.display()
# Out:
# |
# |    65.00
# \------[D] #0
#         | bid
#         | low               300.00  -100.00
#         +-------------------------------[C] #1
#         |                                | competitor_bid
#         |                                | low             .3500   400.00  -100.00
#         |                                +-------------------------------------[C] #2
#         |                                |                                      | cost
#         |                                |                                      | low             .2500   200.00 :   100.00 .0000
#         |                                |                                      | medium          .5000   400.00 :  -100.00 .0000
#         |                                |                                      \ high            .2500   600.00 :  -300.00 .0000
#         |                                | competitor_bid
#         |                                | medium          .5000   600.00  -100.00
#         |                                +-------------------------------------[C] #6
#         |                                |                                      | cost
#         |                                |                                      | low             .2500   200.00 :   100.00 .0000
#         |                                |                                      | medium          .5000   400.00 :  -100.00 .0000
#         |                                |                                      \ high            .2500   600.00 :  -300.00 .0000
#         |                                | competitor_bid
#         |                                | high            .1500   800.00  -100.00
#         |                                \-------------------------------------[C] #10
#         |                                                                       | cost
#         |                                                                       | low             .2500   200.00 :   100.00 .0000
#         |                                                                       | medium          .5000   400.00 :  -100.00 .0000
#         |                                                                       \ high            .2500   600.00 :  -300.00 .0000
#         | bid
#         > medium            500.00    65.00
#         +-------------------------------[C] #14
#         |                                | competitor_bid
#         |                                | low             .3500   400.00     0.00
#         |                                +-------------------------------------[C] #15
#         |                                |                                      | cost
#         |                                |                                      | low             .2500   200.00 :     0.00 .0875
#         |                                |                                      | medium          .5000   400.00 :     0.00 .1750
#         |                                |                                      \ high            .2500   600.00 :     0.00 .0875
#         |                                | competitor_bid
#         |                                | medium          .5000   600.00   100.00
#         |                                +-------------------------------------[C] #19
#         |                                |                                      | cost
#         |                                |                                      | low             .2500   200.00 :   300.00 .1250
#         |                                |                                      | medium          .5000   400.00 :   100.00 .2500
#         |                                |                                      \ high            .2500   600.00 :  -100.00 .1250
#         |                                | competitor_bid
#         |                                | high            .1500   800.00   100.00
#         |                                \-------------------------------------[C] #23
#         |                                                                       | cost
#         |                                                                       | low             .2500   200.00 :   300.00 .0375
#         |                                                                       | medium          .5000   400.00 :   100.00 .0750
#         |                                                                       \ high            .2500   600.00 :  -100.00 .0375
#         | bid
#         | high              700.00    45.00
#         +-------------------------------[C] #27
#         |                                | competitor_bid
#         |                                | low             .3500   400.00     0.00
#         |                                +-------------------------------------[C] #28
#         |                                |                                      | cost
#         |                                |                                      | low             .2500   200.00 :     0.00 .0000
#         |                                |                                      | medium          .5000   400.00 :     0.00 .0000
#         |                                |                                      \ high            .2500   600.00 :     0.00 .0000
#         |                                | competitor_bid
#         |                                | medium          .5000   600.00     0.00
#         |                                +-------------------------------------[C] #32
#         |                                |                                      | cost
#         |                                |                                      | low             .2500   200.00 :     0.00 .0000
#         |                                |                                      | medium          .5000   400.00 :     0.00 .0000
#         |                                |                                      \ high            .2500   600.00 :     0.00 .0000
#         |                                | competitor_bid
#         |                                | high            .1500   800.00   300.00
#         |                                \-------------------------------------[C] #36
#         |                                                                       | cost
#         |                                                                       | low             .2500   200.00 :   500.00 .0000
#         |                                                                       | medium          .5000   400.00 :   300.00 .0000
#         |                                                                       \ high            .2500   600.00 :   100.00 .0000
#         \ no-bid              0.00 :     0.00 .0000

# %% [markdown]
# # Fig. 5

# %%
tree.plot(policy_suggestion=True)

# %%
tree.display(policy_suggestion=True)
# Out:
# |
# |    65.00
# \------[D] #0
#         | bid
#         > medium            500.00    65.00
#         \-------------------------------[C] #14
#                                          | competitor_bid
#                                          | low             .3500   400.00     0.00
#                                          +-------------------------------------[C] #15
#                                          |                                      | cost
#                                          |                                      | low             .2500   200.00 :     0.00 .0875
#                                          |                                      | medium          .5000   400.00 :     0.00 .1750
#                                          |                                      \ high            .2500   600.00 :     0.00 .0875
#                                          | competitor_bid
#                                          | medium          .5000   600.00   100.00
#                                          +-------------------------------------[C] #19
#                                          |                                      | cost
#                                          |                                      | low             .2500   200.00 :   300.00 .1250
#                                          |                                      | medium          .5000   400.00 :   100.00 .2500
#                                          |                                      \ high            .2500   600.00 :  -100.00 .1250
#                                          | competitor_bid
#                                          | high            .1500   800.00   100.00
#                                          \-------------------------------------[C] #23
#                                                                                 | cost
#                                                                                 | low             .2500   200.00 :   300.00 .0375
#                                                                                 | medium          .5000   400.00 :   100.00 .0750
#                                                                                 \ high            .2500   600.00 :  -100.00 .0375

# %%
tree.display(max_deep=2)
# Out:
# |
# |    65.00
# \------[D] #0
#         | bid
#         | low               300.00  -100.00
#         +-------------------------------[C] #1
#         |                                | competitor_bid
#         |                                | low             .3500   400.00  -100.00
#         |                                | medium          .5000   600.00  -100.00
#         |                                | high            .1500   800.00  -100.00
#         | bid
#         > medium            500.00    65.00
#         +-------------------------------[C] #14
#         |                                | competitor_bid
#         |                                | low             .3500   400.00     0.00
#         |                                | medium          .5000   600.00   100.00
#         |                                | high            .1500   800.00   100.00
#         | bid
#         | high              700.00    45.00
#         +-------------------------------[C] #27
#         |                                | competitor_bid
#         |                                | low             .3500   400.00     0.00
#         |                                | medium          .5000   600.00     0.00
#         |                                | high            .1500   800.00   300.00
#         \ no-bid              0.00 :     0.00 .0000

# %% [markdown]
# # Fig. 5.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
tree.probabilistic_sensitivity(varname="cost", plot=True)

# %% [markdown]
# # Fig. 6

# %%
plt.figure(figsize=(10, 8))
tree.value_sensitivity(
    name="cost",
    branch="high",
    values=(450, 750),
    plot=True,
)

# %% [markdown]
# # Fig. 7

# %%
plt.figure(figsize=(10, 6))

tree.risk_sensitivity(
    utility_fn="exp",
    risk_tolerance=75,
    plot=True,
)

# %% [markdown]
# # Fig. 8

# %%
plt.figure(figsize=(10, 7))

tree.risk_profile(idx=0, cumulative=True, single=False, plot=True)

# %%
tree.plot(policy_suggestion=True, max_deep=2)
